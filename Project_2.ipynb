# %% [markdown]
# <a href="https://colab.research.google.com/github/Rihazul/Python_project/blob/main/Project_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Author: Rihazul Islam & Jamal Manzoor

# %% [markdown]
# # Introduction

# %% [markdown]
#   We will be looking to see if we can detect early stages of diabetes by looking at the symptoms and effects that diabetes typically has on an individual. Our question is mainly focused on the fact that if it is possible to have diabetes based on the common symptoms of a diabetic patient.We will be using machine learning to determine if we can accurately predict if some one has diabetes in its early stages. Diabetes is one of the fastest growing life-threatening diseases in the world that affects about 422 million people, the majority of which are living in low- and middle-income countries. Since diabetes has a rather long asymptomatic phase, if it can be detected in its earlier phase, the outcome of a patient can drastically change. Around 50% of people suffering from diabetes are undiagnosed because of its long-term asymptomatic phase. It is only possible to detect diabetes in its early phase by properly assessing both common and less common sign symptoms, which could be found in different phases from disease initiation up to diagnosis.

# %% [markdown]
# This research was conducted by these people M M Faniqul Islam,
# Rahatara Ferdousi,
# Sadikur Rahman,
# and Humayra
# Yasmin Bushra
# from University of Syleth in Bangladesh

# %% [markdown]
# # Importing Data in Study

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/00529/diabetes_data_upload.csv')
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)


df.head(10)
# Out:
#    Age Gender Polyuria Polydipsia sudden weight loss weakness Polyphagia  \
# 0   40   Male       No        Yes                 No      Yes         No
# 1   58   Male       No         No                 No      Yes         No
# 2   41   Male      Yes         No                 No      Yes        Yes
# 3   45   Male       No         No                Yes      Yes        Yes
# 4   60   Male      Yes        Yes                Yes      Yes        Yes
# 5   55   Male      Yes        Yes                 No      Yes        Yes
# 6   57   Male      Yes        Yes                 No      Yes        Yes
# 7   66   Male      Yes        Yes                Yes      Yes         No
# 8   67   Male      Yes        Yes                 No      Yes        Yes
# 9   70   Male       No        Yes                Yes      Yes        Yes
#
#   Genital thrush visual blurring Itching Irritability delayed healing  \
# 0             No              No     Yes           No             Yes
# ...

# %%
numeric_vars=['Age']

categorical_vars=['Gender', 'Polyuria', 'Polydipsia', 'sudden weight loss',
       'weakness', 'Polyphagia', 'Genital thrush', 'visual blurring',
       'Itching', 'Irritability', 'delayed healing', 'partial paresis',
       'muscle stiffness', 'Alopecia', 'Obesity']
       
#target of this analysis          
class_vars=['class']

# %% [markdown]
# # Extracting all the information of this dataframe

# %% [markdown]
# # Data Set Information:
#
# The data has been collected using direct questionnaires from the patients of Sylhet Diabetes Hospital, located in Sylhet, Bangladesh and approved by a doctor.
#
# **Polyuria**: condition where the body urinates more than usual and urinating an abnormally large amounts of urine each time
#
# **Polydipsia**: Feeling of extreme thirstiness
#
# **Sudden weight loss**: weight loss of 10 pounds or five percent of body weight in a short period of time
#
# **Weakness**: loss of muscle strength
#
# **Polyphagia**: Excessive or extreme hunger, even after eating more food
#
# **Genital thrush**: type of yeast infection called Candida, can be irritating and painful
#
# **Blurred vision**: Lack of sharpness of vision, inability to see fine detail
#
# **Itching**: Irritating sensation that makes you want to scratch your skin
#
# **Irritability**: feeling of agitation
#
# **Delayed healing**: wound has trouble healing or staying closed
#
# **Partial paresis**: involves the weakening of a muscle or group of muscle, unlike paralysis, you can still move the muscles
#
# **Muscle Stiffness**: When the muscle feels tight or difficult to move
#
# **Alopecia**: Condition that causes hair to fall out in small patches
#
# **Obesity**: excessive amount of body fat that presents a risk to health

# %%
#case counts of diabetes
df['class'].value_counts()
# Out:
# Positive    320
# Negative    200
# Name: class, dtype: int64

# %%
#number of participants per gender in this study
df['Gender'].value_counts()
# Out:
# Male      328
# Female    192
# Name: Gender, dtype: int64

# %%
#making the group age 
df['age'] = pd.cut(df['Age'], bins=[20, 40, 65, 90])
case_group=df.groupby(['class','Gender'])['age'].value_counts()

#summarising the data frame for each symptomes
disease1_group=df.groupby(['class','age','Gender'])['Polyuria'].value_counts()
disease2_group=df.groupby(['class','age','Gender'])['Polydipsia'].value_counts()
disease3_group=df.groupby(['class','age','Gender'])['sudden weight loss'].value_counts()
disease4_group=df.groupby(['class','age','Gender'])['weakness'].value_counts()
disease5_group=df.groupby(['class','age','Gender'])['Polyphagia'].value_counts()
disease6_group=df.groupby(['class','age','Gender'])['Genital thrush'].value_counts()
disease7_group=df.groupby(['class','age','Gender'])['visual blurring'].value_counts()
disease8_group=df.groupby(['class','age','Gender'])['Itching'].value_counts()
disease9_group=df.groupby(['class','age','Gender'])['Irritability'].value_counts()
disease10_group=df.groupby(['class','age','Gender'])['delayed healing'].value_counts()
disease11_group=df.groupby(['class','age','Gender'])['partial paresis'].value_counts()
disease12_group=df.groupby(['class','age','Gender'])['muscle stiffness'].value_counts()
disease13_group=df.groupby(['class','age','Gender'])['Alopecia'].value_counts()
disease14_group=df.groupby(['class','age','Gender'])['Obesity'].value_counts()


print(case_group)
# Out:
# class     Gender  age
# Negative  Female  (40, 65]     12
#                   (20, 40]      7
#           Male    (40, 65]    103
#                   (20, 40]     62
#                   (65, 90]     16
# Positive  Female  (40, 65]     91
#                   (20, 40]     67
#                   (65, 90]     15
#           Male    (40, 65]     95
#                   (20, 40]     31
#                   (65, 90]     20
# Name: age, dtype: int64

# %%
#making a new table for the original data summary
string=[disease1_group,disease2_group,disease3_group,disease4_group,disease5_group,disease6_group,disease7_group,disease8_group,disease9_group,disease10_group,disease11_group,disease12_group,disease13_group,disease14_group]
new_df=pd.concat(string,axis=1,ignore_index=False)
new_df=new_df.fillna(0)
print('Summary of data frame')
new_df.head(25)
# Out:
# Summary of data frame
#                               Polyuria  Polydipsia  sudden weight loss  \
# Negative (20, 40] Female No        7.0         7.0                 6.0
#                          Yes       0.0         0.0                 1.0
#                   Male   No       62.0        59.0                48.0
#                          Yes       0.0         3.0                14.0
#          (40, 65] Female No       12.0        12.0                12.0
#                          Yes       0.0         0.0                 0.0
#                   Male   No       98.0        98.0                89.0
#                          Yes       5.0         5.0                14.0
#          (65, 90] Male   No        6.0        16.0                16.0
#                          Yes      10.0         0.0                 0.0
# Positive (20, 40] Female No       15.0        17.0                27.0
#                          Yes      52.0        50.0                40.0
# ...

# %% [markdown]
# It is crucial to group the data based on the diabetes cases, the age gap of each gender because physical attributes of all these persons are not the same and diabetes reacts differently to each body type. In this summary, it was necessary to display the age group per gender because naturally diabetes is more affective for old population than young population.

# %% [markdown]
# We want to focus more on the positive cases of diabetes to get the information of which type of syptoms diabetic people have to make a prediction. This prediction will tell which symptom is affective for a diabetic diseases to prevent an occuring stage of early diabetes.

# %% [markdown]
# # Getting the average percentage of each symptoms on the positive cases of diabetes

# %% [markdown]
# Our prediction is based on the average percentage of diabetic people who have the symptoms they experience the most. With this study, we will make a graph that will explain our model nicely.

# %%
#getting the ratios between the yes and no values
idx=pd.IndexSlice
yes=new_df.loc[idx['Positive',:,:,'Yes'],:].values

# %%
no=new_df.loc[idx['Positive',:,:,'No'],:].values

# %% [markdown]
# We are trying to get the ratios of the yes side of the positive dataset in order to get the percentage.

# %%
#arrays of all the ratios
total=new_df.loc[idx['Positive',:,:,'No'],:].values + new_df.loc[idx['Positive',:,:,'Yes'],:].values
no_percent=(no/total)
yes_percent=(yes/total)
print('all ratios for no answers\n',no_percent)
print('all ratios for yes answers\n', yes_percent)
# Out:
# all ratios for no answers
#  [[0.2238806  0.25373134 0.40298507 0.31343284 0.46268657 0.97014925
#   0.46268657 0.52238806 0.73134328 0.46268657 0.31343284 0.49253731
#   0.95522388 0.95522388]
#  [0.38709677 0.5483871  0.74193548 0.64516129 0.77419355 0.41935484
#   0.90322581 0.5483871  0.77419355 0.5483871  0.80645161 0.74193548
#   0.48387097 0.74193548]
#  [0.2967033  0.31868132 0.28571429 0.35164835 0.25274725 0.9010989
#   0.41758242 0.54945055 0.72527473 0.53846154 0.24175824 0.57142857
#   0.93406593 0.73626374]
#  [0.15789474 0.23157895 0.42105263 0.22105263 0.46315789 0.58947368
#   0.41052632 0.54736842 0.56842105 0.56842105 0.51578947 0.64210526
#   0.6        0.78947368]
#  [0.13333333 0.13333333 0.4        0.2        0.33333333 0.6
#   0.         0.06666667 0.73333333 0.33333333 0.53333333 0.53333333
#   0.66666667 0.8       ]
#  [0.3        0.35       0.5        0.2        0.2        0.55
#   0.4        0.5        0.25       0.5        0.1        0.35
# ...

# %%
#making a visual table of the ratios between the Yes and No
df_n=pd.DataFrame(no_percent,index=['Female  age (20,40]','Male  age (20,40]','Female  age (40,65]','Male  age (40,65]','Female  age (65,90]','Male  age (65,90]'],
                  columns=['Polyuria','Polydipsia','sudden weight loss','weakness','Polyphagia','Genital thrush','visual blurring','Itching','Irritability','delayed healing','partial paresis','muscle stiffness','Alopecia','Obesity'])
                  
df_y=pd.DataFrame(yes_percent,index=['Female  age (20,40]','Male  age (20,40]','Female  age (40,65]','Male  age (40,65]','Female  age (65,90]','Male  age (65,90]'],
                  columns=['Polyuria','Polydipsia','sudden weight loss','weakness','Polyphagia','Genital thrush','visual blurring','Itching','Irritability','delayed healing','partial paresis','muscle stiffness','Alopecia','Obesity'])
df_n.rename_axis("No")
# Out:
#                      Polyuria  Polydipsia  sudden weight loss  weakness  \
# No
# Female  age (20,40]  0.223881    0.253731            0.402985  0.313433
# Male  age (20,40]    0.387097    0.548387            0.741935  0.645161
# Female  age (40,65]  0.296703    0.318681            0.285714  0.351648
# Male  age (40,65]    0.157895    0.231579            0.421053  0.221053
# Female  age (65,90]  0.133333    0.133333            0.400000  0.200000
# Male  age (65,90]    0.300000    0.350000            0.500000  0.200000
#
#                      Polyphagia  Genital thrush  visual blurring   Itching  \
# No
# Female  age (20,40]    0.462687        0.970149         0.462687  0.522388
# Male  age (20,40]      0.774194        0.419355         0.903226  0.548387
# Female  age (40,65]    0.252747        0.901099         0.417582  0.549451
# Male  age (40,65]      0.463158        0.589474         0.410526  0.547368
# Female  age (65,90]    0.333333        0.600000         0.000000  0.066667
# ...

# %%
df_y.rename_axis("Yes")
# Out:
#                      Polyuria  Polydipsia  sudden weight loss  weakness  \
# Yes
# Female  age (20,40]  0.776119    0.746269            0.597015  0.686567
# Male  age (20,40]    0.612903    0.451613            0.258065  0.354839
# Female  age (40,65]  0.703297    0.681319            0.714286  0.648352
# Male  age (40,65]    0.842105    0.768421            0.578947  0.778947
# Female  age (65,90]  0.866667    0.866667            0.600000  0.800000
# Male  age (65,90]    0.700000    0.650000            0.500000  0.800000
#
#                      Polyphagia  Genital thrush  visual blurring   Itching  \
# Yes
# Female  age (20,40]    0.537313        0.029851         0.537313  0.477612
# Male  age (20,40]      0.225806        0.580645         0.096774  0.451613
# Female  age (40,65]    0.747253        0.098901         0.582418  0.450549
# Male  age (40,65]      0.536842        0.410526         0.589474  0.452632
# Female  age (65,90]    0.666667        0.400000         1.000000  0.933333
# ...

# %% [markdown]
# **The two dataset represents the percentage between the 'Yes' and 'No' answers for each symptoms based on the gender and group age**

# %%
#printing the average percentages
df_y.rename_axis("Yes").mean()*100
# Out:
# Polyuria              75.018188
# Polydipsia            69.404799
# sudden weight loss    54.138542
# weakness              67.811748
# Polyphagia            58.564690
# Genital thrush        32.832055
# visual blurring       56.766315
# Itching               54.428987
# Irritability          36.957234
# delayed healing       50.811840
# partial paresis       58.153908
# muscle stiffness      44.477667
# Alopecia              31.002876
# Obesity               18.785054
# dtype: float64

# %%
#Making the plot of our model
per=df_y.rename_axis("Yes").mean()*100
avg_df=pd.DataFrame(per,columns=['Percentage %'])
avg_df=avg_df.rename_axis('Symptoms')
avg_df=avg_df.reset_index()
avg_df=avg_df.sort_values(by=['Percentage %'])
avg_df=avg_df.round(decimals=2)


fig, ax = plt.subplots(figsize=(21,9),dpi=300)
d=avg_df['Symptoms']
e=avg_df['Percentage %']

bars = ax.bar(d,e, width=0.5)
for bar in bars:
  height = bar.get_height()
  label_x_pos = bar.get_x() + bar.get_width() / 2 
  ax.text(label_x_pos, height, s=f'{height}', ha='center',
  va='bottom',fontsize=11,color='green')

plt.xticks(rotation=-55) 
plt.grid(True, axis='y', alpha=0.5)
plt.xlabel(
    "Symptoms",
    fontdict ={
        'family': 'serif',
        'color':  'xkcd:black',
        'weight': 'normal',
        'size': 16,
    },
    labelpad=8
)
plt.ylabel(
    "Percentage %",
    fontdict ={
        'family': 'serif',
        'color':  'xkcd:black',
        'weight': 'normal',
        'size': 16,
    },
    labelpad=8
)


plt.title(
    "Figure 1.The Average Percentage of Each Symptoms for Positive Cases of Diabetes", 
    fontdict ={
        'family': 'serif',
        'color':  'xkcd:red',
        'weight': 'bold',
        'size': 24,
    },
    loc='left',
    pad=10
)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# From Figure 1, we can say that Polyuria, Polydipsia and weakness have the highest percentage average for most of the positive cases of diabetes. In fact, we see that 75% average of Polyuria symptom is present for most of the diabetic people, 69% average of Polydipsia symptom is present and 67% of weakness symptom is present. Based on these averages we can make basic prediction that if someone has polyuria and polydipsia, they can potentially have diabetes.

# %% [markdown]
# # Cheking if our prediction made above is really accurate with machine learning.

# %% [markdown]
# As we found the percentage average, we would like to know if our model is pretty accurate or if it can tell that a patient can potentially have diabetes with all the symptoms each of them have.

# %%
#importing all package for machine learning
import numpy as np

from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.linear_model import LogisticRegression

# %%
np.random.seed(0)

X=df.drop(["age","class"],axis=1)
y=df["class"]

# %%
# We create the preprocessing pipelines for both numeric and categorical data.
numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())])

categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='constant', fill_value='missing')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))])

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_vars),
        ('cat', categorical_transformer, categorical_vars)])

clf = Pipeline(steps=[('preprocessor', preprocessor),
                      ('classifier', LogisticRegression(solver="liblinear"))])

# %%
clf.fit(X=X,y=y)
# Out:
# Pipeline(memory=None,
#          steps=[('preprocessor',
#                  ColumnTransformer(n_jobs=None, remainder='drop',
#                                    sparse_threshold=0.3,
#                                    transformer_weights=None,
#                                    transformers=[('num',
#                                                   Pipeline(memory=None,
#                                                            steps=[('imputer',
#                                                                    SimpleImputer(add_indicator=False,
#                                                                                  copy=True,
#                                                                                  fill_value=None,
#                                                                                  missing_values=nan,
#                                                                                  strategy='median',
# ...

# %%
#All the coefficient of the logitic regression
clf['classifier'].coef_
# Out:
# array([[-0.39734716,  1.80026913, -1.37523643, -1.38749484,  1.81252754,
#         -1.51938384,  1.94441654, -0.01889322,  0.44392592, -0.06383923,
#          0.48887193, -0.19411976,  0.61915246, -0.44869989,  0.87373259,
#         -0.0919244 ,  0.5169571 ,  1.07761563, -0.65258293, -0.6709176 ,
#          1.0959503 ,  0.43814199, -0.01310929, -0.26562236,  0.69065506,
#          0.43330128, -0.00826858,  0.24896934,  0.17606336,  0.31180954,
#          0.11322316]])

# %% [markdown]
# **Confusion Matrix**

# %%
#calculation of dataset accuracy
from sklearn.metrics import precision_score,recall_score,f1_score
print('precision score:', precision_score(y_true=y,y_pred=clf.predict(X),pos_label="Positive"))
print('recall score:', recall_score(y_true=y,y_pred=clf.predict(X),pos_label="Positive"))
print('f1 score:',f1_score(y_true=y,y_pred=clf.predict(X),pos_label="Positive"))
# Out:
# precision score: 0.9614147909967846
# recall score: 0.934375
# f1 score: 0.94770206022187

# %% [markdown]
# Based on this tool, we can clearly see that the chance of a person trully getting diabetes from this data is 94% which is a high indication of accuracy. Basically, the prediction made by the machine learning is quite true from the actual result. This information tells us if someone can become diabetic from the symptoms they have the most.

# %% [markdown]
# By using the packages of sklearn.metrics precision score and recal score, we get the accuracy of what percentage the person could potentially have diabetes. In fact, this tool tells us the percentage from true "Positive" values to predicted "Positive" values. ![image.png](data:image/png;base64,...)
#
# link of image:https://blog.exsilio.com/all/accuracy-precision-recall-f1-score-interpretation-of-performance-measures/

# %%
#splitting the dataset to train set and test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30,random_state=1)

clf.fit(X_train, y_train)
# Out:
# Pipeline(memory=None,
#          steps=[('preprocessor',
#                  ColumnTransformer(n_jobs=None, remainder='drop',
#                                    sparse_threshold=0.3,
#                                    transformer_weights=None,
#                                    transformers=[('num',
#                                                   Pipeline(memory=None,
#                                                            steps=[('imputer',
#                                                                    SimpleImputer(add_indicator=False,
#                                                                                  copy=True,
#                                                                                  fill_value=None,
#                                                                                  missing_values=nan,
#                                                                                  strategy='median',
# ...

# %%
###
# https://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html#sphx-glr-auto-examples-model-selection-plot-confusion-matrix-py
###
from sklearn.metrics import confusion_matrix
from sklearn.utils.multiclass import unique_labels
def plot_confusion_matrix(y_true, y_pred, classes,
                          normalize=False,
                          title=None,
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if not title:
        if normalize:
            title = 'Normalized confusion matrix'
        else:
            title = 'Confusion matrix, without normalization'

    # Compute confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    # Only use the labels that appear in the data
#     classes = classes[unique_labels(y_true, y_pred)]
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        # print("Normalized confusion matrix")
    # else:
        # print('Confusion matrix, without normalization')

    # print(cm)

    fig, ax = plt.subplots()
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    # We want to show all ticks...
    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           # ... and label them with the respective list entries
           xticklabels=classes, yticklabels=classes,
           title=title,
           ylabel='True label',
           xlabel='Predicted label')

    # Rotate the tick labels and set their alignment.
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
             rotation_mode="anchor")

    # Loop over data dimensions and create text annotations.
    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    fig.tight_layout()
    return ax

y_pred=clf.predict(X_test)

np.set_printoptions(precision=2)
class_names = df['class'].value_counts().index

# Plot non-normalized confusion matrix
plot_confusion_matrix(y_test, y_pred, classes=class_names,
                      title='Fig3. Confusion matrix, without normalization')

# Plot normalized confusion matrix
plot_confusion_matrix(y_test, y_pred, classes=class_names, normalize=True,
                      title='Fig4. Normalized confusion matrix')

plt.show()

# %% [markdown]
# The confusion matrix is great tool that shows us that 90% of predicted positive class of diabetes is true and 94% of predicted negative classs diabetes is true. The prediction of these machine learning tools are very accurate to determine how an individual with symptoms could get positive or negative cases of diabetes.

# %% [markdown]
# **Decision Tree**

# %%
clf2 = Pipeline(steps=[('preprocessor', preprocessor),
                      ('classifier', DecisionTreeClassifier(max_depth=3))])
clf2.fit(X=X_train,y=y_train)
# Out:
# Pipeline(memory=None,
#          steps=[('preprocessor',
#                  ColumnTransformer(n_jobs=None, remainder='drop',
#                                    sparse_threshold=0.3,
#                                    transformer_weights=None,
#                                    transformers=[('num',
#                                                   Pipeline(memory=None,
#                                                            steps=[('imputer',
#                                                                    SimpleImputer(add_indicator=False,
#                                                                                  copy=True,
#                                                                                  fill_value=None,
#                                                                                  missing_values=nan,
#                                                                                  strategy='median',
# ...

# %%
plt.figure(figsize=(21,9))
tree.plot_tree(clf2.named_steps["classifier"],filled=True,rounded=True, class_names=['Negative','Positive'])
plt.title(
    "Figure 2.Decision Tree diagram", 
    fontdict ={
        'family': 'serif',
        'color':  'xkcd:red',
        'weight': 'bold',
        'size': 22,
    },
    loc='left',
    pad=10
)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# Figure 2 is a decision tree diagram that shows the path where the end result is positive or negative based on the features name. In this case, there are 31 features name, from all the symptoms, there is the yes and no categories, from the gender if it is male or female, and the age which is a single non categorical feature.

# %% [markdown]
# # Conclusion

# %% [markdown]
# To conclude this project, we have answered our question that asks which symptoms can make a person diabetic and how accurate this result can be with machine learning if our model is close to that accuracy. With the f1 score and the confusion matrix, the chances to be diabetec or not to be diabetic is really high as close to 95%. This indication shows that the computer can easily predict who gets to be diabetic with the symptoms that are more present on diabetic people. Also, our model from figure 1 shows that 75% of polyuria symptom and 69% of polydipsia symptom can occur to a diabetic person. These two indication have a huge gap on determining who can become diabetic from this dataset.

# %% [markdown]
# # Reference

# %% [markdown]
# Reference:
#
# Google Colaboratory
# https://colab.research.google.com/drive/1MyVKXPo7klgAIxAEfz7XJ9hvCUrB2qPa#scrollTo=PsC8rczdCVOq by Sameer Bhatnagar for machine learning
#
# and https://colab.research.google.com/drive/1HqGnYLor_rCVV0Jm19nQkX9_AjbsjQzq?usp=sharing by Jonathan Sumner for visual plotting
#
# All information on the dataset
# https://archive.ics.uci.edu/ml/machine-learning-databases/00529/diabetes_data_upload.csv
# https://link.springer.com/chapter/10.1007/978-981-13-8798-2_12
# https://archive.ics.uci.edu/ml/datasets/Early+stage+diabetes+risk+prediction+dataset. Dataset of our study
#
# https://www.youtube.com/watch?v=q90UDEgYqeI&t=3491s&ab_channel=StatQuestwithJoshStarmerStatQuestwithJoshStarmerVerified
#
# https://www.datacamp.com/community/tutorials/decision-tree-classification-python
#
# https://kb.databricks.com/machine-learning/extract-feature-info.html
#
# https://machinelearningmastery.com/calculate-feature-importance-with-python/
#
# definitions of symptoms : https://www.medicinenet.com/script/main/hp.asp
